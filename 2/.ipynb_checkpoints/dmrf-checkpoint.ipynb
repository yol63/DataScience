# %% [markdown]
# # Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Список объектов

# %%
import requests
objids = set()

for i in range(11):
    offset_ = 0 + i*1000
    limit_ = 1000
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/сервисы/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
    res = requests.get(url)
    objects_data = res.json()
    objects_list = objects_data.get('data').get('list')
    objids_temp = {x.get('objId') for x in objects_list}
    objids = objids.union(objids_temp)
    print('запрос ' + str(i + 1) + ' ответ ' + str(res) + ' длина сета ' + str(len(objids)))
# Out:
# запрос 1 ответ <Response [200]> длина сета 1000
# запрос 2 ответ <Response [200]> длина сета 1999
# запрос 3 ответ <Response [200]> длина сета 2999
# запрос 4 ответ <Response [200]> длина сета 3999
# запрос 5 ответ <Response [200]> длина сета 4999
# запрос 6 ответ <Response [200]> длина сета 5999
# запрос 7 ответ <Response [200]> длина сета 6999
# запрос 8 ответ <Response [200]> длина сета 7999
# запрос 9 ответ <Response [200]> длина сета 8999
# запрос 10 ответ <Response [200]> длина сета 9999
# запрос 11 ответ <Response [200]> длина сета 10106

# %% [markdown]
# # Данные по определенному объекту

# %%
import pandas as pd
df = pd.DataFrame()
i = 0

for object_ in objids:
    i = i+1
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/сервисы/api/object/{object_}'
    res = requests.get(url)
    df_temp = pd.json_normalize(res.json().get('data'))
    df = pd.concat([df,df_temp], ignore_index = True)
#    print(str(i) + ': ' + str(object_))

df
# Out:
#           id    pdId  region  \
# 0      32787  181636      16
# 1      32793  162963      50
# 2      32811  182065      54
# 3      32812  182065      54
# 4      32813  182065      54
# ...      ...     ...     ...
# 10101  32629  173074      27
# 10102  32677  174688      69
# 10103  32709  178109      77
# 10104  32710   90412      50
# 10105  32736  173973      59
#
#                                                  address  \
# 0      г Набережные Челны, вдоль проспекта Яшьлек, бл...
# 1                г Красногорск, район Марьино, корпус 25
# 2                 с/с Барышевский, д. 100 (строительный)
# 3                 с/с Барышевский, д. 101 (строительный)
# 4                 с/с Барышевский, д. 102 (строительный)
# ...                                                  ...
# 10101        город Хабаровск, переулок Гражданский, д. 9
# 10102    г Тверь, ул Планерная, д. 10, блок-секция 7,8,9
# 10103             г Москва, набережная Павелецкая, вл. 8
# 10104              г Дзержинский, улица Угрешская, д. 19
# 10105                      г Пермь, улица Ленская, д. 30
#
#                                           nameObj  floorMin  floorMax  \
# 0                                ЖК "Современный"      12.0      13.0
# 1                             Микрогород "В лесу"       9.0      13.0
# 2          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# 3          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# 4          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# ...                                           ...       ...       ...
# 10101                   Жилой Комплекс "Кристалл"      25.0      25.0
# 10102  ЖК "Созвездие", ЖИЛОЙ КОМПЛЕКС "СОЗВЕЗДИЕ"      11.0      11.0
# 10103                     Резиденции композиторов       1.0      18.0
# 10104         Red.19 (Республика Дзержинский, 19)       9.0       9.0
# 10105                      Жилой дом "Курья парк"      25.0      25.0
#
#        objElemLivingCnt objReady100PercDt wallMaterialShortDesc  ...  \
# 0                    99        2022-12-31        Монолит-кирпич  ...
# 1                   545        2023-03-31        Монолит-кирпич  ...
# 2                     2        2024-03-31                Кирпич  ...
# 3                     2        2024-03-31                Кирпич  ...
# 4                     2        2024-03-31                Кирпич  ...
# ...                 ...               ...                   ...  ...
# 10101                89        2022-06-30        Монолит-кирпич  ...
# 10102               129        2024-09-30                Другое  ...
# 10103               122        2022-06-30        Монолит-кирпич  ...
# 10104                 0        2022-09-30        Монолит-кирпич  ...
# 10105               156        2023-03-31                Другое  ...
#
#       metro.color metro.time  metro.isWalk  metro.colors transportDistIndex  \
# 0             NaN        NaN           NaN           NaN                NaN
# 1         #0072BA  23.583333         False     [#0072BA]                NaN
# 2             NaN        NaN           NaN           NaN             3 / 10
# 3             NaN        NaN           NaN           NaN             2 / 10
# 4             NaN        NaN           NaN           NaN             2 / 10
# ...           ...        ...           ...           ...                ...
# 10101         NaN        NaN           NaN           NaN                NaN
# 10102         NaN        NaN           NaN           NaN                NaN
# 10103     #ADACAC  16.033333         False     [#ADACAC]             8 / 10
# 10104         NaN        NaN           NaN           NaN                NaN
# 10105         NaN        NaN           NaN           NaN                NaN
#
#       developer.bankruptStage.bankruptStageCd  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 10101                                     NaN
# 10102                                     NaN
# 10103                                     NaN
# 10104                                     NaN
# 10105                                     NaN
#
#       developer.bankruptStage.bankruptStageDesc  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10101                                       NaN
# 10102                                       NaN
# 10103                                       NaN
# 10104                                       NaN
# 10105                                       NaN
#
#       developer.bankruptStage.bankruptLawUrl developer.orgBankruptMsgDttm  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 10101                                    NaN                          NaN
# 10102                                    NaN                          NaN
# 10103                                    NaN                          NaN
# 10104                                    NaN                          NaN
# 10105                                    NaN                          NaN
#
#        complexShortNm
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 10101             NaN
# 10102             NaN
# 10103             NaN
# 10104             NaN
# 10105             NaN
#
# [10106 rows x 104 columns]

# %%
df
# Out:
#           id    pdId  region  \
# 0      32787  181636      16
# 1      32793  162963      50
# 2      32811  182065      54
# 3      32812  182065      54
# 4      32813  182065      54
# ...      ...     ...     ...
# 10101  32629  173074      27
# 10102  32677  174688      69
# 10103  32709  178109      77
# 10104  32710   90412      50
# 10105  32736  173973      59
#
#                                                  address  \
# 0      г Набережные Челны, вдоль проспекта Яшьлек, бл...
# 1                г Красногорск, район Марьино, корпус 25
# 2                 с/с Барышевский, д. 100 (строительный)
# 3                 с/с Барышевский, д. 101 (строительный)
# 4                 с/с Барышевский, д. 102 (строительный)
# ...                                                  ...
# 10101        город Хабаровск, переулок Гражданский, д. 9
# 10102    г Тверь, ул Планерная, д. 10, блок-секция 7,8,9
# 10103             г Москва, набережная Павелецкая, вл. 8
# 10104              г Дзержинский, улица Угрешская, д. 19
# 10105                      г Пермь, улица Ленская, д. 30
#
#                                           nameObj  floorMin  floorMax  \
# 0                                ЖК "Современный"      12.0      13.0
# 1                             Микрогород "В лесу"       9.0      13.0
# 2          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# 3          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# 4          Коттеджный поселок "Горки Академпарка"       1.0       1.0
# ...                                           ...       ...       ...
# 10101                   Жилой Комплекс "Кристалл"      25.0      25.0
# 10102  ЖК "Созвездие", ЖИЛОЙ КОМПЛЕКС "СОЗВЕЗДИЕ"      11.0      11.0
# 10103                     Резиденции композиторов       1.0      18.0
# 10104         Red.19 (Республика Дзержинский, 19)       9.0       9.0
# 10105                      Жилой дом "Курья парк"      25.0      25.0
#
#        objElemLivingCnt objReady100PercDt wallMaterialShortDesc  ...  \
# 0                    99        2022-12-31        Монолит-кирпич  ...
# 1                   545        2023-03-31        Монолит-кирпич  ...
# 2                     2        2024-03-31                Кирпич  ...
# 3                     2        2024-03-31                Кирпич  ...
# 4                     2        2024-03-31                Кирпич  ...
# ...                 ...               ...                   ...  ...
# 10101                89        2022-06-30        Монолит-кирпич  ...
# 10102               129        2024-09-30                Другое  ...
# 10103               122        2022-06-30        Монолит-кирпич  ...
# 10104                 0        2022-09-30        Монолит-кирпич  ...
# 10105               156        2023-03-31                Другое  ...
#
#       metro.color metro.time  metro.isWalk  metro.colors transportDistIndex  \
# 0             NaN        NaN           NaN           NaN                NaN
# 1         #0072BA  23.583333         False     [#0072BA]                NaN
# 2             NaN        NaN           NaN           NaN             3 / 10
# 3             NaN        NaN           NaN           NaN             2 / 10
# 4             NaN        NaN           NaN           NaN             2 / 10
# ...           ...        ...           ...           ...                ...
# 10101         NaN        NaN           NaN           NaN                NaN
# 10102         NaN        NaN           NaN           NaN                NaN
# 10103     #ADACAC  16.033333         False     [#ADACAC]             8 / 10
# 10104         NaN        NaN           NaN           NaN                NaN
# 10105         NaN        NaN           NaN           NaN                NaN
#
#       developer.bankruptStage.bankruptStageCd  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 10101                                     NaN
# 10102                                     NaN
# 10103                                     NaN
# 10104                                     NaN
# 10105                                     NaN
#
#       developer.bankruptStage.bankruptStageDesc  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10101                                       NaN
# 10102                                       NaN
# 10103                                       NaN
# 10104                                       NaN
# 10105                                       NaN
#
#       developer.bankruptStage.bankruptLawUrl developer.orgBankruptMsgDttm  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 10101                                    NaN                          NaN
# 10102                                    NaN                          NaN
# 10103                                    NaN                          NaN
# 10104                                    NaN                          NaN
# 10105                                    NaN                          NaN
#
#        complexShortNm
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 10101             NaN
# 10102             NaN
# 10103             NaN
# 10104             NaN
# 10105             NaN
#
# [10106 rows x 104 columns]

# %% [markdown]
# # Сохранение данных

# %%
df.to_excel('dmrf.xlsx')

import pickle
df.to_pickle('dmrf.pkl')

import sqlite3
conn = sqlite3.connect('dmrf_database')
df = df.applymap(str)
df.to_sql('dmrf', conn, if_exists='replace', index = False)
conn.commit()
conn.close()
